# %%
import pandas as pd

edu = pd.read_csv(r'ACSDT5Y2020.B06009-2022-08-03T035735.csv')

# %%
edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Columns: 105 entries, Label (Grouping) to Puerto Rico!!Margin of Error
# dtypes: float64(2), object(103)
# memory usage: 24.7+ KB

# %%
pd.set_option('display.max_columns', None)
edu
# Out:
#                                      Label (Grouping) Alabama!!Estimate  \
# 0                                              Total:         3,344,006
# 1                      Less than high school graduate           438,947
# 2         High school graduate (includes equivalency)         1,014,342
# 3                  Some college or associate's degree         1,013,673
# 4                                   Bachelor's degree           546,674
# 5                     Graduate or professional degree           330,370
# 6                         Born in state of residence:         2,166,432
# 7                      Less than high school graduate           304,025
# 8           High school graduate (includes equival...           724,871
# 9                  Some college or associate's degree           657,492
# 10                                  Bachelor's degree           312,934
# 11                    Graduate or professional degree           167,110
# ...

# %%
edu = edu.drop(edu.columns[[2,4,6,8,10,12,14,16,17,18,20,22,24,26,28,30,32,34,36,38,40,42,44,46,48,50,52,54,56,58,60,62,64,66,68,70,72,74,76,78,80,82,84,86,88,90,92,94,96,98,100,102,103,104]],axis=1)
edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Label (Grouping)          30 non-null     object
#  1   Alabama!!Estimate         30 non-null     object
#  2   Alaska!!Estimate          30 non-null     object
#  3   Arizona!!Estimate         30 non-null     object
#  4   Arkansas!!Estimate        30 non-null     object
#  5   California!!Estimate      30 non-null     object
#  6   Colorado!!Estimate        30 non-null     object
#  7   Connecticut!!Estimate     30 non-null     object
#  8   Delaware!!Estimate        30 non-null     object
#  9   Florida!!Estimate         30 non-null     object
#  10  Georgia!!Estimate         30 non-null     object
#  11  Hawaii!!Estimate          30 non-null     object
#  12  Idaho!!Estimate           30 non-null     object
# ...

# %%
edu.rename(columns= {'Label (Grouping)':'Label', 'Alabama!!Estimate':'Alabama', 'Alaska!!Estimate':'Alaska', 'Arizona!!Estimate':'Arizona', 'Arkansas!!Estimate':'Arkansas',
            'California!!Estimate':'California', 'Colorado!!Estimate':'Colorado', 'Connecticut!!Estimate':'Connecticut', 'Delaware!!Estimate':'Delaware', 'Florida!!Estimate':'Florida',
            'Georgia!!Estimate':'Georgia', 'Hawaii!!Estimate':'Hawaii', 'Idaho!!Estimate':'Idaho', 'Illinois!!Estimate':'Illinois', 'Indiana!!Estimate':'Indiana', 'Iowa!!Estimate':'Iowa',
            'Kansas!!Estimate':'Kansas', 'Kentucky!!Estimate':'Kentucky', 'Louisiana!!Estimate':'Louisiana', 'Maine!!Estimate':'Maine', 'Maryland!!Estimate':'Maryland',
            'Massachusetts!!Estimate':'Massachusetts', 'Michigan!!Estimate':'Michigan', 'Minnesota!!Estimate':'Minnesota', 'Mississippi!!Estimate':'Mississippi', 'Missouri!!Estimate':'Missouri',
            'Montana!!Estimate':'Montana', 'Nebraska!!Estimate':'Nebraska', 'Nevada!!Estimate':'Nevada', 'New Hampshire!!Estimate':'New Hampshire', 'New Jersey!!Estimate':'New Jersey',
            'New Mexico!!Estimate':'New Mexico', 'New York!!Estimate':'New York', 'North Carolina!!Estimate':'North Carolina', 'North Dakota!!Estimate':'North Dakota', 'Ohio!!Estimate':'Ohio',
            'Oklahoma!!Estimate':'Oklahoma', 'Oregon!!Estimate':'Oregon', 'Pennsylvania!!Estimate':'Pennsylvania', 'Rhode Island!!Estimate':'Rhode Island', 'South Carolina!!Estimate':'South Carolina',
            'South Dakota!!Estimate':'South Dakota', 'Tennessee!!Estimate':'Tennessee', 'Texas!!Estimate':'Texas', 'Utah!!Estimate':'Utah', 'Vermont!!Estimate':'Vermont', 'Virginia!!Estimate':'Virginia',
            'Washington!!Estimate':'Washington', 'West Virginia!!Estimate':'West Virginia', 'Wisconsin!!Estimate':'Wisconsin', 'Wyoming!!Estimate':'Wyoming'}, inplace= True)

# %%
edu = edu.iloc[:5]
edu
# Out:
#                                              Label    Alabama   Alaska  \
# 0                                           Total:  3,344,006  483,436
# 1                   Less than high school graduate    438,947   33,176
# 2      High school graduate (includes equivalency)  1,014,342  137,486
# 3               Some college or associate's degree  1,013,673  167,807
# 4                                Bachelor's degree    546,674   90,161
#
#      Arizona   Arkansas  California   Colorado Connecticut Delaware  \
# 0  4,846,056  2,026,722  26,665,143  3,900,754   2,489,205  679,870
# 1    587,919    260,360   4,286,538    308,785     225,550   63,843
# 2  1,151,988    686,812   5,431,385    827,081     655,381  210,998
# 3  1,637,451    596,855   7,690,347  1,142,035     612,274  182,986
# 4    911,228    308,648   5,764,827  1,015,989     551,459  129,092
#
#       Florida    Georgia   Hawaii      Idaho   Illinois    Indiana       Iowa  \
# ...

# %%
edu = edu.transpose()

edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Label to Wyoming
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       51 non-null     object
#  1   1       51 non-null     object
#  2   2       51 non-null     object
#  3   3       51 non-null     object
#  4   4       51 non-null     object
# dtypes: object(5)
# memory usage: 4.4+ KB

# %%
edu.rename(columns= {0:'Total Population', 1:'Less than high school graduate', 2:'High school graduate (includes equivalency)', 3:'Some college or associate degree',
                    4:'Bachelors Degreee'}, inplace= True)

# %%
edu = edu.drop('Label')
edu
# Out:
#                Total Population Less than high school graduate  \
# Alabama               3,344,006                        438,947
# Alaska                  483,436                         33,176
# Arizona               4,846,056                        587,919
# Arkansas              2,026,722                        260,360
# California           26,665,143                      4,286,538
# Colorado              3,900,754                        308,785
# Connecticut           2,489,205                        225,550
# Delaware                679,870                         63,843
# Florida              15,255,326                      1,751,798
# Georgia               6,996,425                        848,653
# Hawaii                  996,423                         74,875
# Idaho                 1,145,344                        100,189
# Illinois              8,686,700                        898,338
# Indiana               4,466,180                        476,425
# ...

# %%
edu.to_csv('edu.csv')
education = pd.read_csv(r'edu.csv')

# %%
education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   50 non-null     object
#  1   Total Population                             50 non-null     object
#  2   Less than high school graduate               50 non-null     object
#  3   High school graduate (includes equivalency)  50 non-null     object
#  4   Some college or associate degree             50 non-null     object
#  5   Bachelors Degreee                            50 non-null     object
# dtypes: object(6)
# memory usage: 2.5+ KB

# %%
education.rename(columns= {'Unnamed: 0':'State',}, inplace= True)
education
# Out:
#              State Total Population Less than high school graduate  \
# 0          Alabama        3,344,006                        438,947
# 1           Alaska          483,436                         33,176
# 2          Arizona        4,846,056                        587,919
# 3         Arkansas        2,026,722                        260,360
# 4       California       26,665,143                      4,286,538
# 5         Colorado        3,900,754                        308,785
# 6      Connecticut        2,489,205                        225,550
# 7         Delaware          679,870                         63,843
# 8          Florida       15,255,326                      1,751,798
# 9          Georgia        6,996,425                        848,653
# 10          Hawaii          996,423                         74,875
# 11           Idaho        1,145,344                        100,189
# 12        Illinois        8,686,700                        898,338
# ...

# %%
education.to_csv('Education by state.csv')
