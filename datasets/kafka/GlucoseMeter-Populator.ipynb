# %% [markdown]
# # `GlucoseMeter` Populator

# %% [markdown]
# ## Part 1: Set-Up

# %%
# Imports
import uuid
from confluent_kafka.admin import AdminClient, NewTopic
from pyspark.sql.functions import col

# Get config
from config import user
from config import password
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Mount point through Oauth security.
storageAccount = "gen10datafund2205"
storageContainer = "group5container"
clientSecret = "-ZS8Q~NwOKfwEpVOg3Teb1pPtxDbz616XjlXLbuU"
clientid = "2ca50102-5717-4373-b796-39d06568588d"
mount_point = "/mnt/jacklynn/glucmeter" 

configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": clientid,
       "fs.azure.account.oauth2.client.secret": clientSecret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/d46b54b2-a652-420b-aa5a-2ef7f8fc706e/oauth2/token",
       "fs.azure.createRemoteFileSystemDuringInitialization": "true"}

# Unmount if exists
try: 
    dbutils.fs.unmount(mount_point)
except:
    pass

# Mount to database
dbutils.fs.mount(
    source = "abfss://"+storageContainer+"@"+storageAccount+".dfs.core.windows.net/",
    mount_point = mount_point,
    extra_configs = configs)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: True</div>

# %%
# %fs 
ls /mnt/jacklynn/glucmeter
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/jacklynn/glucmeter/CGM_Data.csv</td><td>CGM_Data.csv</td><td>35978185</td><td>1659468631000</td></tr><tr><td>dbfs:/mnt/jacklynn/glucmeter/Diabetes Prevalence in the US by State and Demographic.csv</td><td>Diabetes Prevalence in the US by State and Demographic.csv</td><td>180068</td><td>1659497875000</td></tr><tr><td>dbfs:/mnt/jacklynn/glucmeter/ExerciseData_2013_150min.csv</td><td>ExerciseData_2013_150min.csv</td><td>2107</td><td>1659554693000</td></tr><tr><td>dbfs:/mnt/jacklynn/glucmeter/Food Insecurity.csv</td><td>Food Insecurity.csv</td><td>6779</td><td>1659533925000</td></tr><tr><td>dbfs:/mnt/jacklynn/glucmeter/U.S. NHANES Survey Data.csv</td><td>U.S. NHANES Survey Data.csv</td><td>724469</td><td>1659554890000</td></tr><tr><td>dbfs:/mnt/jacklynn/glucmeter/chinese-diabetes-clean.csv</td><td>chinese-diabetes-clean.csv</td><td>33367142</td><td>1659541878000</td></tr></tbody></table></div>

# %% [markdown]
# ## Part 2: Populate `GlucoseMeter` Table

# %%
# Get data
df = spark.read.options(
    inferSchema='True',
    delimiter=',',
    header='True'
    ).csv('/mnt/jacklynn/glucmeter/CGM_Data.csv')

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>RecID</th><th>PtID</th><th>DeviceDtTm</th><th>Glucose</th></tr></thead><tbody><tr><td>0</td><td>196879</td><td>220</td><td>2000-04-28T18:20:14.010+0000</td><td>129</td></tr><tr><td>1</td><td>196880</td><td>220</td><td>2000-04-28T18:25:14.010+0000</td><td>132</td></tr><tr><td>2</td><td>196881</td><td>220</td><td>2000-04-28T18:30:14.010+0000</td><td>126</td></tr><tr><td>3</td><td>196882</td><td>220</td><td>2000-04-28T18:35:14.010+0000</td><td>120</td></tr><tr><td>4</td><td>196883</td><td>220</td><td>2000-04-28T18:40:14.010+0000</td><td>118</td></tr><tr><td>5</td><td>196884</td><td>220</td><td>2000-04-28T18:45:14.010+0000</td><td>115</td></tr><tr><td>6</td><td>196885</td><td>220</td><td>2000-04-28T18:50:14.010+0000</td><td>107</td></tr><tr><td>7</td><td>196886</td><td>220</td><td>2000-04-28T18:55:14.010+0000</td><td>107</td></tr><tr><td>8</td><td>196887</td><td>220</td><td>2000-04-28T19:00:14.010+0000</td><td>106</td></tr><tr><td>9</td><td>196888</td><td>220</td><td>2000-04-28T19:05:14.010+0000</td><td>105</td></tr><tr><td>10</td><td>196889</td><td>220</td><td>2000-04-28T19:10:14.010